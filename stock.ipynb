# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
url = "https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp?symbolCode=7057&symbol=IBULHSGFIN&symbol=IBULHSGFIN&instrument=OPTSTK&date=-&segmentLink=17&segmentLink=17"

# %%
browser = webdriver.Chrome("./chromedriver")
browser.get(url)
html = browser.page_source
browser.close()

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
curr_price = float(soup.find('b').text.strip().split()[1])
lower = 0.85*curr_price
upper = 1.15*curr_price

# %%
data = []
columns = []
table = soup.find('table', id="octable")

table_head = table.find('thead')
rows = table_head.find_all('tr')

cols = rows[1].find_all('th')
cols = [ele.text.strip() for ele in cols]
columns = [ele for ele in cols if ele]

table_body = table.find('tbody')
rows = table_body.find_all('tr')

for row in rows[2:-1]:
    cols = row.find_all('td')
    cols = [ele.text.strip().replace(',', '') for ele in cols if ele.text.strip()]
    data.append([float(ele) if ele != '-' else 0 for ele in cols]) # Get rid of empty values

df = pd.DataFrame(data, columns=columns[1:-1])
df
# Out:
#            OI  Chng in OI  Volume     IV    LTP  Net Chng   BidQty  BidPrice  \
# 0      3100.0         0.0     0.0   0.00  52.00      0.00  71300.0     58.55
# 1         0.0         0.0     0.0   0.00   0.00      0.00  71300.0     54.30
# 2         0.0         0.0     0.0   0.00   0.00      0.00  71300.0     50.00
# 3         0.0         0.0     0.0   0.00   0.00      0.00   6200.0     51.25
# 4     18600.0         0.0     0.0   0.00  42.50      0.00   9300.0     47.00
# 5      6200.0         0.0     0.0   0.00  25.90      0.00   6200.0     43.40
# 6     15500.0     -3100.0     2.0  87.28  41.50      7.05   6200.0     38.40
# 7      3100.0         0.0     0.0   0.00  29.65      0.00   6200.0     36.05
# 8    170500.0   -117800.0   155.0  79.23  33.10      0.10   3100.0     32.85
# 9     31000.0     -3100.0     4.0  75.96  29.20      4.30  24800.0     29.20
# 10   179800.0     31000.0    35.0  81.58  27.30      3.30   3100.0     26.60
# 11    49600.0     -3100.0     5.0  81.89  24.70      2.45  15500.0     23.55
# 12   666500.0    -31000.0   313.0  80.45  21.80      2.20   3100.0     21.70
# 13   251100.0    130200.0   147.0  80.31  19.40      4.40   3100.0     19.35
# 14  1081900.0    675800.0   887.0  80.99  17.25      0.40   3100.0     17.25
# 15    96100.0     80600.0    92.0  79.22  15.00     -0.65   3100.0     15.00
# 16   523900.0    294500.0   518.0  80.42  13.70      1.90   9300.0     13.40
# 17    31000.0     24800.0    11.0  81.13  12.05     -0.75   6200.0     11.65
# 18  1131500.0    523900.0   700.0  80.72  10.65      0.10   3100.0     10.35
# 19    55800.0     12400.0    11.0  81.42   9.35     -1.65   6200.0      8.90
# 20   381300.0    217000.0   342.0  81.99   8.30     -0.70   3100.0      8.25
# 21    58900.0     24800.0    12.0  80.71   7.00     -2.00   3100.0      6.95
# 22   282100.0     18600.0    98.0  82.39   6.40     -0.05   3100.0      6.30
# 23   192200.0     83700.0    83.0  83.66   5.60      0.65   3100.0      5.55
#
#     AskPrice   AskQty  ...   BidQty  BidPrice  AskPrice   AskQty  Net Chng  \
# 0      75.55  71300.0  ...   3100.0      1.50      1.80  12400.0     -0.95
# 1      71.65  71300.0  ...   3100.0      1.45      2.75  18600.0      0.00
# 2      65.65  71300.0  ...   3100.0      2.40      2.60   6200.0     -1.25
# 3      54.80   6200.0  ...   9300.0      2.50      3.65  18600.0      0.00
# 4      50.65   9300.0  ...   6200.0      3.60      3.75   3100.0     -0.10
# 5      46.35  15500.0  ...  21700.0      4.30      5.75  24800.0    -24.25
# 6      42.55  27900.0  ...   6200.0      5.65      5.95   6200.0     -1.85
# 7      37.40   6200.0  ...   3100.0      6.95      7.25   3100.0     -3.50
# 8      33.10   3100.0  ...  12400.0      8.25      8.50  18600.0     -0.75
# 9      30.90   3100.0  ...  24800.0      9.90     10.70   3100.0     -3.80
# 10     27.45   3100.0  ...  12400.0     12.00     12.40   6200.0     -5.05
# 11     24.85   3100.0  ...   3100.0     14.35     15.20   3100.0     -3.40
# 12     22.05   3100.0  ...  12400.0     16.90     17.15   6200.0     -0.35
# 13     19.90   6200.0  ...   9300.0     19.25     19.85   3100.0     -3.45
# 14     17.50   6200.0  ...   3100.0     22.25     22.95   3100.0     -5.95
# 15     15.50   3100.0  ...  24800.0     24.90     26.25   6200.0      0.00
# 16     13.60   6200.0  ...  18600.0     28.25     29.30   6200.0     -4.50
# 17     12.30   9300.0  ...  12400.0     31.70     32.90   3100.0      0.00
# 18     10.65   3100.0  ...  18600.0     35.10     36.50   6200.0     -5.65
# 19      9.90   6200.0  ...  18600.0     38.75     40.60  18600.0      0.00
# 20      8.55   6200.0  ...   9300.0     42.95     45.55   9300.0     -4.50
# 21      7.55   3100.0  ...  12400.0     46.70     48.35   6200.0      0.00
# 22      6.60   3100.0  ...  24800.0     50.50     52.50   6200.0      0.00
# 23      5.70   3100.0  ...  34100.0     54.80     56.90  34100.0      0.00
#
#       LTP     IV  Volume  Chng in OI        OI
# 0    1.30  87.17    22.0     62000.0  145700.0
# 1    0.00   0.00     0.0         0.0       0.0
# 2    2.50  86.02    26.0     43400.0  155000.0
# 3    0.00   0.00     0.0         0.0       0.0
# 4    3.75  82.39    24.0     18600.0  170500.0
# 5    5.25  85.55     7.0     15500.0   21700.0
# 6    5.65  80.45    39.0    -24800.0  170500.0
# 7    7.50  80.96    24.0      3100.0   31000.0
# 8    8.50  79.87   281.0    195300.0  623100.0
# 9   10.10  79.36    12.0     21700.0   77500.0
# 10  12.40  80.22   102.0     74400.0  198400.0
# 11  14.60  80.95    10.0      9300.0   86800.0
# 12  17.15  81.60   173.0     86800.0  266600.0
# 13  19.70  81.38    37.0     40300.0   52700.0
# 14  23.35  84.89    38.0     65100.0   99200.0
# 15  29.75   0.00     0.0         0.0    3100.0
# 16  28.75  81.76     5.0      9300.0   24800.0
# 17   0.00   0.00     0.0         0.0       0.0
# 18  35.35  80.69     1.0      3100.0   15500.0
# 19   0.00   0.00     0.0         0.0       0.0
# 20  42.30  78.21     1.0      3100.0    6200.0
# 21   0.00   0.00     0.0         0.0       0.0
# 22   0.00   0.00     0.0         0.0       0.0
# 23   0.00   0.00     0.0         0.0       0.0
#
# [24 rows x 21 columns]

# %%
relevant = df[df['Strike Price'].between(lower, upper)]
put_relevant = df[df['Strike Price'].between(lower, curr_price)]
call_relevant = df[df['Strike Price'].between(curr_price, upper)]

# %%
relevant = relevant.iloc[:, [4,6,7,8,9,10,11,12,13,14,16]]
put_relevant = put_relevant.iloc[:, [10,12,13]]
call_relevant = call_relevant.iloc[:, [7,8,10]]

# %%
relevant
# Out:
#       LTP   BidQty  BidPrice  AskPrice   AskQty  Strike Price   BidQty  \
# 6   41.50   6200.0     38.40     42.55  27900.0         190.0   6200.0
# 7   29.65   6200.0     36.05     37.40   6200.0         195.0   3100.0
# 8   33.10   3100.0     32.85     33.10   3100.0         200.0  12400.0
# 9   29.20  24800.0     29.20     30.90   3100.0         205.0  24800.0
# 10  27.30   3100.0     26.60     27.45   3100.0         210.0  12400.0
# 11  24.70  15500.0     23.55     24.85   3100.0         215.0   3100.0
# 12  21.80   3100.0     21.70     22.05   3100.0         220.0  12400.0
# 13  19.40   3100.0     19.35     19.90   6200.0         225.0   9300.0
# 14  17.25   3100.0     17.25     17.50   6200.0         230.0   3100.0
# 15  15.00   3100.0     15.00     15.50   3100.0         235.0  24800.0
# 16  13.70   9300.0     13.40     13.60   6200.0         240.0  18600.0
# 17  12.05   6200.0     11.65     12.30   9300.0         245.0  12400.0
# 18  10.65   3100.0     10.35     10.65   3100.0         250.0  18600.0
# 19   9.35   6200.0      8.90      9.90   6200.0         255.0  18600.0
#
#     BidPrice  AskPrice   AskQty    LTP
# 6       5.65      5.95   6200.0   5.65
# 7       6.95      7.25   3100.0   7.50
# 8       8.25      8.50  18600.0   8.50
# 9       9.90     10.70   3100.0  10.10
# 10     12.00     12.40   6200.0  12.40
# 11     14.35     15.20   3100.0  14.60
# 12     16.90     17.15   6200.0  17.15
# 13     19.25     19.85   3100.0  19.70
# 14     22.25     22.95   3100.0  23.35
# 15     24.90     26.25   6200.0  29.75
# 16     28.25     29.30   6200.0  28.75
# 17     31.70     32.90   3100.0   0.00
# 18     35.10     36.50   6200.0  35.35
# 19     38.75     40.60  18600.0   0.00

# %%
put_relevant['AvgPrice'] = (put_relevant["BidPrice"] + put_relevant["AskPrice"])/2
put_relevant2 = put_relevant.iloc[:, [0,3]]
put_relevant2
# Out:
#     Strike Price  AvgPrice
# 6          190.0     5.800
# 7          195.0     7.100
# 8          200.0     8.375
# 9          205.0    10.300
# 10         210.0    12.200
# 11         215.0    14.775
# 12         220.0    17.025

# %%
call_relevant['AvgPrice'] = (call_relevant["BidPrice"] + call_relevant["AskPrice"])/2
call_relevant2 = call_relevant.iloc[:, [2, 3]]
call_relevant2
# Out:
#     Strike Price  AvgPrice
# 13         225.0    19.625
# 14         230.0    17.375
# 15         235.0    15.250
# 16         240.0    13.500
# 17         245.0    11.975
# 18         250.0    10.500
# 19         255.0     9.400

# %%
curr_price
# Out:
# 223.5

# %%
import csv

# %%
op = pd.read_csv("fo_mktlots.csv")

# %%
option_list = list(op[op.columns[1]])[3:]

# %%
import requests
url = 'https://www.google.com/search?q=moneycontrol+'
o = 'ACC'

# %%
response = requests.get(url + o)
soup = BeautifulSoup(response.content, "html.parser")

# %%
o_orl = soup.findAll("a")[16]['href'].split('q=')[1].split('&')[0]

# %%
response = requests.get(o_url)

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
market = float(soup.find(id="div_nse_livebox_wrap").find("span", {"class": "span_price_wrap stprh red_hilight rdclr"}).getText())

# %%
book = float(soup.findAll("div", {"class": "value_txtfr"})[2].getText())

# %%
eps = float(soup.findAll("div", {"class": "value_txtfr"})[6].getText())
# Out:
# 61.62

# %%
ind_pe = float(soup.findAll("div", {"class": "value_txtfr"})[5].getText())

# %%
pe = float(soup.findAll("div", {"class": "value_txtfr"})[1].getText())
